# %%
# !pip install requests
# !pip3 install beautifulsoup4
# Out:
# Looking in indexes: https://artifactory.blackstone.com/artifactory/api/pypi/python/simple
# ...
# Looking in indexes: https://artifactory.blackstone.com/artifactory/api/pypi/python/simple
# ...

# %%
import requests

# %%
response = requests.get('http://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html')
response.text
# Out:
# '\n\n<!DOCTYPE html>\n<!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html lang="en-us" class="no-js"> <!--<![endif]-->\n    <head>\n        <title>\n    Food and Drink | \n     Books to Scrape - Sandbox\n\n</title>\n\n        <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n        <meta name="created" content="24th Jun 2016 09:29" />\n        <meta name="description" content="\n    \n" />\n        <meta name="viewport" content="width=device-width" />\n        <meta name="robots" content="NOARCHIVE,NOCACHE" />\n\n        <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->\n        <!--[if lt IE 9]>\n        <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>\n        <![endif]-->\n\n        \n            <link
# ...

# %%
import bs4

# %%
soup = bs4.BeautifulSoup(response.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     Food and Drink |
#      Books to Scrape - Sandbox
#
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="
#
# " name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="../../../../static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
image_info = soup.select('.thumbnail')

# %%
image_info
# Out:
# [<img alt="Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More" class="thumbnail" src="../../../../media/cache/9f/59/9f59f01fa916a7bb8f0b28a4012179a4.jpg"/>,
#  <img alt="The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!" class="thumbnail" src="../../../../media/cache/b7/f4/b7f4843dbe062d44be1ffcfa16b2faa4.jpg"/>,
#  <img alt="My Paris Kitchen: Recipes and Stories" class="thumbnail" src="../../../../media/cache/f5/65/f565af3d9dd20a1ad72a1e7c4157387d.jpg"/>,
#  <img alt="Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed" class="thumbnail" src="../../../../media/cache/10/c6/10c61093002db1fec4089d8076678624.jpg"/>,
# ...

# %%
len(image_info)
# Out:
# 20

# %%
source_one=image_info[0].get('src')
print(source_one)
# Out:
# ../../../../media/cache/9f/59/9f59f01fa916a7bb8f0b28a4012179a4.jpg

# %%
## http://books.toscrape.com/media/cache/fd/af/fdaf3c3104c559941c01e840fecd2659.jpg is the src of one image

links = []
for link in image_info:
    #the links is in the 'src' attribute 
    item =link.get('src')
    #we're adding https: to format it properly 
    print(item)
    #this if statement is bc some <div> tags also have the class "thumbnail"
    if type(item) is str: 
        clean_item=item.split('../../../../',1)[1]
        #print(type(item))
        links.append('http://books.toscrape.com/'+clean_item)
# Out:
# ../../../../media/cache/9f/59/9f59f01fa916a7bb8f0b28a4012179a4.jpg
# ../../../../media/cache/b7/f4/b7f4843dbe062d44be1ffcfa16b2faa4.jpg
# ../../../../media/cache/f5/65/f565af3d9dd20a1ad72a1e7c4157387d.jpg
# ../../../../media/cache/10/c6/10c61093002db1fec4089d8076678624.jpg
# ../../../../media/cache/98/d1/98d1c979c4bac9e147a6718946578b0f.jpg
# ../../../../media/cache/61/bd/61bdfe3950643c47d70c37c4123530f3.jpg
# ../../../../media/cache/0d/1f/0d1f3f934460f5a50aaa8c366641234c.jpg
# ../../../../media/cache/54/89/54899b4584e941ceced511d81092c88a.jpg
# ../../../../media/cache/20/f2/20f28657b49f8cb24ed2ec6448bb6df3.jpg
# ../../../../media/cache/c4/dc/c4dcec6f513eaca3f0f3c748d834c46d.jpg
# ../../../../media/cache/fe/67/fe67c381d6a0c4c00a7c191d16939554.jpg
# ../../../../media/cache/b8/38/b838b65e0e1ac3a9b498dfb1bf004420.jpg
# ../../../../media/cache/74/aa/74aa29b1ba4147eaf5b46671bf235861.jpg
# ../../../../media/cache/76/a1/76a1516c8d9c3e620626f30840013a85.jpg
# ...

# %%
links
# Out:
# ['http://books.toscrape.com/media/cache/9f/59/9f59f01fa916a7bb8f0b28a4012179a4.jpg',
#  'http://books.toscrape.com/media/cache/b7/f4/b7f4843dbe062d44be1ffcfa16b2faa4.jpg',
#  'http://books.toscrape.com/media/cache/f5/65/f565af3d9dd20a1ad72a1e7c4157387d.jpg',
#  'http://books.toscrape.com/media/cache/10/c6/10c61093002db1fec4089d8076678624.jpg',
#  'http://books.toscrape.com/media/cache/98/d1/98d1c979c4bac9e147a6718946578b0f.jpg',
#  'http://books.toscrape.com/media/cache/61/bd/61bdfe3950643c47d70c37c4123530f3.jpg',
#  'http://books.toscrape.com/media/cache/0d/1f/0d1f3f934460f5a50aaa8c366641234c.jpg',
#  'http://books.toscrape.com/media/cache/54/89/54899b4584e941ceced511d81092c88a.jpg',
#  'http://books.toscrape.com/media/cache/20/f2/20f28657b49f8cb24ed2ec6448bb6df3.jpg',
#  'http://books.toscrape.com/media/cache/c4/dc/c4dcec6f513eaca3f0f3c748d834c46d.jpg',
#  'http://books.toscrape.com/media/cache/fe/67/fe67c381d6a0c4c00a7c191d16939554.jpg',
# ...

# %%
import urllib.request #to download 
import urllib.parse # to download 
from urllib.error import HTTPError # to see error 
import time # to keep track of time 
import random as r # to donwload at random time

# %%
def download(url, full_path):
    try:
        urllib.request.urlretrieve(url, full_path)
        time.sleep(r.randint(1, 5))
    except urllib.error.HTTPError as err:
        print(err.code)
        pass

# %%
#enumerate() take 2 parameters, iterable, start (optional)
#iterable iterates through the object (in our case, a list of links)

#first, create folder called "images"

for index, url in enumerate(links):
    print(url)
    file_name = 'img_' + str(index) + '.jpg'
    file_path = 'images/'    
    full_path = '{}{}'.format(file_path, file_name)
    print(file_name)
    download(url, full_path)
# Out:
# http://books.toscrape.com/media/cache/9f/59/9f59f01fa916a7bb8f0b28a4012179a4.jpg
# img_0.jpg
# http://books.toscrape.com/media/cache/b7/f4/b7f4843dbe062d44be1ffcfa16b2faa4.jpg
# img_1.jpg
# http://books.toscrape.com/media/cache/f5/65/f565af3d9dd20a1ad72a1e7c4157387d.jpg
# img_2.jpg
# http://books.toscrape.com/media/cache/10/c6/10c61093002db1fec4089d8076678624.jpg
# img_3.jpg
# http://books.toscrape.com/media/cache/98/d1/98d1c979c4bac9e147a6718946578b0f.jpg
# img_4.jpg
# http://books.toscrape.com/media/cache/61/bd/61bdfe3950643c47d70c37c4123530f3.jpg
# img_5.jpg
# http://books.toscrape.com/media/cache/0d/1f/0d1f3f934460f5a50aaa8c366641234c.jpg
# img_6.jpg
# http://books.toscrape.com/media/cache/54/89/54899b4584e941ceced511d81092c88a.jpg
# img_7.jpg
# http://books.toscrape.com/media/cache/20/f2/20f28657b49f8cb24ed2ec6448bb6df3.jpg
# img_8.jpg
# http://books.toscrape.com/media/cache/c4/dc/c4dcec6f513eaca3f0f3c748d834c46d.jpg
# img_9.jpg
# ...

# %%
response = requests.get('http://books.toscrape.com/catalogue/category/books/food-and-drink_33/page-2.html')
response.text
# Out:
# '\n\n<!DOCTYPE html>\n<!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html lang="en-us" class="no-js"> <!--<![endif]-->\n    <head>\n        <title>\n    Food and Drink | \n     Books to Scrape - Sandbox\n\n</title>\n\n        <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n        <meta name="created" content="24th Jun 2016 09:30" />\n        <meta name="description" content="\n    \n" />\n        <meta name="viewport" content="width=device-width" />\n        <meta name="robots" content="NOARCHIVE,NOCACHE" />\n\n        <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->\n        <!--[if lt IE 9]>\n        <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>\n        <![endif]-->\n\n        \n            <link
# ...

# %%
soup = bs4.BeautifulSoup(response.text, 'html.parser')

# %%
links_two = []
for link in image_info:
    #the links is in the 'src' attribute 
    item =link.get('src')
    #we're adding https: to format it properly 
    print(item)
    #this if statement is bc some <div> tags also have the class "thumbnail"
    if type(item) is str: 
        clean_item=item.split('../../../../',1)[1]
        #print(type(item))
        links_two.append('http://books.toscrape.com/'+clean_item)
# Out:
# ../../../../media/cache/9f/59/9f59f01fa916a7bb8f0b28a4012179a4.jpg
# ../../../../media/cache/b7/f4/b7f4843dbe062d44be1ffcfa16b2faa4.jpg
# ../../../../media/cache/f5/65/f565af3d9dd20a1ad72a1e7c4157387d.jpg
# ../../../../media/cache/10/c6/10c61093002db1fec4089d8076678624.jpg
# ../../../../media/cache/98/d1/98d1c979c4bac9e147a6718946578b0f.jpg
# ../../../../media/cache/61/bd/61bdfe3950643c47d70c37c4123530f3.jpg
# ../../../../media/cache/0d/1f/0d1f3f934460f5a50aaa8c366641234c.jpg
# ../../../../media/cache/54/89/54899b4584e941ceced511d81092c88a.jpg
# ../../../../media/cache/20/f2/20f28657b49f8cb24ed2ec6448bb6df3.jpg
# ../../../../media/cache/c4/dc/c4dcec6f513eaca3f0f3c748d834c46d.jpg
# ../../../../media/cache/fe/67/fe67c381d6a0c4c00a7c191d16939554.jpg
# ../../../../media/cache/b8/38/b838b65e0e1ac3a9b498dfb1bf004420.jpg
# ../../../../media/cache/74/aa/74aa29b1ba4147eaf5b46671bf235861.jpg
# ../../../../media/cache/76/a1/76a1516c8d9c3e620626f30840013a85.jpg
# ...

# %%
for index, url in enumerate(links_two):
    print(url)
    file_name = 'img_' + str(index+20) + '.jpg'
    file_path = 'images/'    
    full_path = '{}{}'.format(file_path, file_name)
    print(file_name)
    download(url, full_path)
# Out:
# http://books.toscrape.com/media/cache/9f/59/9f59f01fa916a7bb8f0b28a4012179a4.jpg
# img_20.jpg
# http://books.toscrape.com/media/cache/b7/f4/b7f4843dbe062d44be1ffcfa16b2faa4.jpg
# img_21.jpg
# http://books.toscrape.com/media/cache/f5/65/f565af3d9dd20a1ad72a1e7c4157387d.jpg
# img_22.jpg
# http://books.toscrape.com/media/cache/10/c6/10c61093002db1fec4089d8076678624.jpg
# img_23.jpg
# http://books.toscrape.com/media/cache/98/d1/98d1c979c4bac9e147a6718946578b0f.jpg
# img_24.jpg
# http://books.toscrape.com/media/cache/61/bd/61bdfe3950643c47d70c37c4123530f3.jpg
# img_25.jpg
# http://books.toscrape.com/media/cache/0d/1f/0d1f3f934460f5a50aaa8c366641234c.jpg
# img_26.jpg
# http://books.toscrape.com/media/cache/54/89/54899b4584e941ceced511d81092c88a.jpg
# img_27.jpg
# http://books.toscrape.com/media/cache/20/f2/20f28657b49f8cb24ed2ec6448bb6df3.jpg
# img_28.jpg
# http://books.toscrape.com/media/cache/c4/dc/c4dcec6f513eaca3f0f3c748d834c46d.jpg
# img_29.jpg
# ...
